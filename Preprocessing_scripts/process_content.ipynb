# %%
from os import cpu_count
from joblib import Parallel, delayed
import swifter
# first lets run clean_text on the 'content' column
from cleantext import clean
def clean_text(s):
    return clean(s,lower=True,                     # lowercase text
        no_urls=True,                  # replace all URLs with a special token
        no_emails=True,                # replace all email addresses with a special token
        no_numbers=True,               # replace all numbers with a special token
        replace_with_url="<URL>",
        replace_with_email="<EMAIL>",
        replace_with_number="<NUM>",
        lang="en"                   
    )

# clean the text
def clean_column(series):
    # parallelized operation
    return Parallel(n_jobs=cpu_count())(delayed(clean_text)(s) for s in series)

from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')

def tokenize_column(series):
    # parallelized operation
    return Parallel(n_jobs=cpu_count())(delayed(word_tokenize)(s) for s in series)
    
state = False

from nltk.corpus import stopwords
# removing generic stopwords
def remove_stopwords(series):
    stop_words = set(stopwords.words('english'))
    # parallelized operation
    return Parallel(n_jobs=cpu_count())(delayed(lambda x: [w for w in x if not w in stop_words])(s) for s in series)

# lemmatizing the text
from nltk.stem import WordNetLemmatizer
def lemmatize_column(series):
    lemmatizer = WordNetLemmatizer()
    # parallelized operation
    return Parallel(n_jobs=cpu_count())(delayed(lambda x: [lemmatizer.lemmatize(w) for w in x])(s) for s in series)
    

# remove punctiuation
import string
def remove_punctuation(series):
    # parallelized operation
    return Parallel(n_jobs=cpu_count())(delayed(lambda x: [w for w in x if w not in string.punctuation])(s) for s in series)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\musta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\musta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#csv file in chunks
import pandas as pd

df = pd.read_csv('fake_news_cleaned.csv', parse_dates=['scraped_at', 'inserted_at', 'updated_at'], chunksize=1000)

# %%
for i, chunk in enumerate(df):
    # Drop the unnecessary columns
    chunk = chunk['content']

    # clean the text
    chunk = clean_column(chunk)
    chunk = tokenize_column(chunk)
    chunk = remove_stopwords(chunk)
    chunk = lemmatize_column(chunk)
    chunk = remove_punctuation(chunk)

    # convert list back to series
    chunk = pd.Series(chunk)

    # save to file. Append if file exists, otherwise create new file
    if i == 0:
        chunk.to_csv('fake_news_cleaned_tokenized.csv', mode='w', index=False)
    else:
        chunk.to_csv('fake_news_cleaned_tokenized.csv', mode='a', header=False, index=False)

    # print progress
    print('processed {} rows'.format((i+1)*1000))
# Out:
# processed 1000 rows
# processed 2000 rows
# processed 3000 rows
# processed 4000 rows
# processed 5000 rows
# processed 6000 rows
# processed 7000 rows
# processed 8000 rows
# processed 9000 rows
# processed 10000 rows
# processed 11000 rows
# processed 12000 rows
# processed 13000 rows
# processed 14000 rows
# processed 15000 rows
# processed 16000 rows
# processed 17000 rows
# processed 18000 rows
# processed 19000 rows
# processed 20000 rows
# processed 21000 rows
# processed 22000 rows
# processed 23000 rows
# processed 24000 rows
# processed 25000 rows
# processed 26000 rows
# processed 27000 rows
# processed 28000 rows
# processed 29000 rows
# processed 30000 rows
# processed 31000 rows
# processed 32000 rows
# processed 33000 rows
# processed 34000 rows
# processed 35000 rows
# processed 36000 rows
# processed 37000 rows
# processed 38000 rows
# processed 39000 rows
# processed 40000 rows
# processed 41000 rows
# processed 42000 rows
# processed 43000 rows
# processed 44000 rows
# processed 45000 rows
# processed 46000 rows
# processed 47000 rows
# processed 48000 rows
# processed 49000 rows
# processed 50000 rows
# processed 51000 rows
# processed 52000 rows
# processed 53000 rows
# processed 54000 rows
# processed 55000 rows
# processed 56000 rows
# processed 57000 rows
# processed 58000 rows
# processed 59000 rows
# processed 60000 rows
# processed 61000 rows
# processed 62000 rows
# processed 63000 rows
# processed 64000 rows
# processed 65000 rows
# processed 66000 rows
# processed 67000 rows
# processed 68000 rows
# processed 69000 rows
# processed 70000 rows
# processed 71000 rows
# processed 72000 rows
# processed 73000 rows
# processed 74000 rows
# processed 75000 rows
# processed 76000 rows
# processed 77000 rows
# processed 78000 rows
# processed 79000 rows
# processed 80000 rows
# processed 81000 rows
# processed 82000 rows
# processed 83000 rows
# processed 84000 rows
# processed 85000 rows
# processed 86000 rows
# processed 87000 rows
# processed 88000 rows
# processed 89000 rows
# processed 90000 rows
# processed 91000 rows
# processed 92000 rows
# processed 93000 rows
# processed 94000 rows
# processed 95000 rows
# processed 96000 rows
# processed 97000 rows
# processed 98000 rows
# processed 99000 rows
# processed 100000 rows
# processed 101000 rows
# processed 102000 rows
# processed 103000 rows
# processed 104000 rows
# processed 105000 rows
# processed 106000 rows
# processed 107000 rows
# processed 108000 rows
# processed 109000 rows
# processed 110000 rows
# processed 111000 rows
# processed 112000 rows
# processed 113000 rows
# processed 114000 rows
# processed 115000 rows
# processed 116000 rows
# processed 117000 rows
# processed 118000 rows
# processed 119000 rows
# processed 120000 rows
# processed 121000 rows
# processed 122000 rows
# processed 123000 rows
# processed 124000 rows
# processed 125000 rows
# processed 126000 rows
# processed 127000 rows
# processed 128000 rows
# processed 129000 rows
# processed 130000 rows
# processed 131000 rows
# processed 132000 rows
# processed 133000 rows
# processed 134000 rows
# processed 135000 rows
# processed 136000 rows
# processed 137000 rows
# processed 138000 rows
# processed 139000 rows
# processed 140000 rows
# processed 141000 rows
# processed 142000 rows
# processed 143000 rows
# processed 144000 rows
# processed 145000 rows
# processed 146000 rows
# processed 147000 rows
# processed 148000 rows
# processed 149000 rows
# processed 150000 rows
# processed 151000 rows
# processed 152000 rows
# processed 153000 rows
# processed 154000 rows
# processed 155000 rows
# processed 156000 rows
# processed 157000 rows
# processed 158000 rows
# processed 159000 rows
# processed 160000 rows
# processed 161000 rows
# processed 162000 rows
# processed 163000 rows
# processed 164000 rows
# processed 165000 rows
# processed 166000 rows
# processed 167000 rows
# processed 168000 rows
# processed 169000 rows
# processed 170000 rows
# processed 171000 rows
# processed 172000 rows
# processed 173000 rows
# processed 174000 rows
# processed 175000 rows
# processed 176000 rows
# processed 177000 rows
# processed 178000 rows
# processed 179000 rows
# processed 180000 rows
# processed 181000 rows
# processed 182000 rows
# processed 183000 rows
# processed 184000 rows
# processed 185000 rows
# processed 186000 rows
# processed 187000 rows
# processed 188000 rows
# processed 189000 rows
# processed 190000 rows
# processed 191000 rows
# processed 192000 rows
# processed 193000 rows
# processed 194000 rows
# processed 195000 rows
# processed 196000 rows
# processed 197000 rows
# processed 198000 rows
# processed 199000 rows
# processed 200000 rows
# processed 201000 rows
# processed 202000 rows
# processed 203000 rows
# processed 204000 rows
# processed 205000 rows
# processed 206000 rows
# processed 207000 rows
# processed 208000 rows
# processed 209000 rows
# processed 210000 rows
# processed 211000 rows
# processed 212000 rows
# processed 213000 rows
# processed 214000 rows
# processed 215000 rows
# processed 216000 rows
# processed 217000 rows
# processed 218000 rows
# processed 219000 rows
# processed 220000 rows
# processed 221000 rows
# processed 222000 rows
# processed 223000 rows
# processed 224000 rows
# processed 225000 rows
# processed 226000 rows
# processed 227000 rows
# processed 228000 rows
# processed 229000 rows
# processed 230000 rows
# processed 231000 rows
# processed 232000 rows
# processed 233000 rows
# processed 234000 rows
# processed 235000 rows
# processed 236000 rows
# processed 237000 rows
# processed 238000 rows
# processed 239000 rows
# processed 240000 rows
# processed 241000 rows
# processed 242000 rows
# processed 243000 rows
# processed 244000 rows
# processed 245000 rows
# processed 246000 rows
# processed 247000 rows
# processed 248000 rows
# processed 249000 rows
# processed 250000 rows
# processed 251000 rows
# processed 252000 rows
# processed 253000 rows
# processed 254000 rows
# processed 255000 rows
# processed 256000 rows
# processed 257000 rows
# processed 258000 rows
# processed 259000 rows
# processed 260000 rows
# processed 261000 rows
# processed 262000 rows
# processed 263000 rows
# processed 264000 rows
# processed 265000 rows
# processed 266000 rows
# processed 267000 rows
# processed 268000 rows
# processed 269000 rows
# processed 270000 rows
# processed 271000 rows
# processed 272000 rows
# processed 273000 rows
# processed 274000 rows
# processed 275000 rows
# processed 276000 rows
# processed 277000 rows
# processed 278000 rows
# processed 279000 rows
# processed 280000 rows
# processed 281000 rows
# processed 282000 rows
# processed 283000 rows
# processed 284000 rows
# processed 285000 rows
# processed 286000 rows
# processed 287000 rows
# processed 288000 rows
# processed 289000 rows
# processed 290000 rows
# processed 291000 rows
# processed 292000 rows
# processed 293000 rows
# processed 294000 rows
# processed 295000 rows
# processed 296000 rows
# processed 297000 rows
# processed 298000 rows
# processed 299000 rows
# processed 300000 rows
# processed 301000 rows
# processed 302000 rows
# processed 303000 rows
# processed 304000 rows
# processed 305000 rows
# processed 306000 rows
# processed 307000 rows
# processed 308000 rows
# processed 309000 rows
# processed 310000 rows
# processed 311000 rows
# processed 312000 rows
# processed 313000 rows
# processed 314000 rows
# processed 315000 rows
# processed 316000 rows
# processed 317000 rows
# processed 318000 rows
# processed 319000 rows
# processed 320000 rows
# processed 321000 rows
# processed 322000 rows
# processed 323000 rows
# processed 324000 rows
# processed 325000 rows
# processed 326000 rows
# processed 327000 rows
# processed 328000 rows
# processed 329000 rows
# processed 330000 rows
# processed 331000 rows
# processed 332000 rows
# processed 333000 rows
# processed 334000 rows
# processed 335000 rows
# processed 336000 rows
# processed 337000 rows
# processed 338000 rows
# processed 339000 rows
# processed 340000 rows
# processed 341000 rows
# processed 342000 rows
# processed 343000 rows
# processed 344000 rows
# processed 345000 rows
# processed 346000 rows
# processed 347000 rows
# processed 348000 rows
# processed 349000 rows
# processed 350000 rows
# processed 351000 rows
# processed 352000 rows
# processed 353000 rows
# processed 354000 rows
# processed 355000 rows
# processed 356000 rows
# processed 357000 rows
# processed 358000 rows
# processed 359000 rows
# processed 360000 rows
# processed 361000 rows
# processed 362000 rows
# processed 363000 rows
# processed 364000 rows
# processed 365000 rows
# processed 366000 rows
# processed 367000 rows
# processed 368000 rows
# processed 369000 rows
# processed 370000 rows
# processed 371000 rows
# processed 372000 rows
# processed 373000 rows
# processed 374000 rows
# processed 375000 rows
# processed 376000 rows
# processed 377000 rows
# processed 378000 rows
# processed 379000 rows
# processed 380000 rows
# processed 381000 rows
# processed 382000 rows
# processed 383000 rows
# processed 384000 rows
# processed 385000 rows
# processed 386000 rows
# processed 387000 rows
# processed 388000 rows
# processed 389000 rows
# processed 390000 rows
# processed 391000 rows
# processed 392000 rows
# processed 393000 rows
# processed 394000 rows
# processed 395000 rows
# processed 396000 rows
# processed 397000 rows
# processed 398000 rows
# processed 399000 rows
# processed 400000 rows
# processed 401000 rows
# processed 402000 rows
# processed 403000 rows
# processed 404000 rows
# processed 405000 rows
# processed 406000 rows
# processed 407000 rows
# processed 408000 rows
# processed 409000 rows
# processed 410000 rows
# processed 411000 rows
# processed 412000 rows
# processed 413000 rows
# processed 414000 rows
# processed 415000 rows
# processed 416000 rows
# processed 417000 rows
# processed 418000 rows
# processed 419000 rows
# processed 420000 rows
# processed 421000 rows
# processed 422000 rows
# processed 423000 rows
# processed 424000 rows
# processed 425000 rows
# processed 426000 rows
# processed 427000 rows
# processed 428000 rows
# processed 429000 rows
# processed 430000 rows
# processed 431000 rows
# processed 432000 rows
# processed 433000 rows
# processed 434000 rows
# processed 435000 rows
# processed 436000 rows
# processed 437000 rows
# processed 438000 rows
# processed 439000 rows
# processed 440000 rows
# processed 441000 rows
# processed 442000 rows
# processed 443000 rows
# processed 444000 rows
# processed 445000 rows
# processed 446000 rows
# processed 447000 rows
# processed 448000 rows
# processed 449000 rows
# processed 450000 rows
# processed 451000 rows
# processed 452000 rows
# processed 453000 rows
# processed 454000 rows
# processed 455000 rows
# processed 456000 rows
# processed 457000 rows
# processed 458000 rows
# processed 459000 rows
# processed 460000 rows
# processed 461000 rows
# processed 462000 rows
# processed 463000 rows
# processed 464000 rows
# processed 465000 rows
# processed 466000 rows
# processed 467000 rows
# processed 468000 rows
# processed 469000 rows
# processed 470000 rows
# processed 471000 rows
# processed 472000 rows
# processed 473000 rows
# processed 474000 rows
# processed 475000 rows
# processed 476000 rows
# processed 477000 rows
# processed 478000 rows
# processed 479000 rows
# processed 480000 rows
# processed 481000 rows
# processed 482000 rows
# processed 483000 rows
# processed 484000 rows
# processed 485000 rows
# processed 486000 rows
# processed 487000 rows
# processed 488000 rows
# processed 489000 rows
# processed 490000 rows
# processed 491000 rows
# processed 492000 rows
# processed 493000 rows
# processed 494000 rows
# processed 495000 rows
# processed 496000 rows
# processed 497000 rows
# processed 498000 rows
# processed 499000 rows
# processed 500000 rows
# processed 501000 rows
# processed 502000 rows
# processed 503000 rows
# processed 504000 rows
# processed 505000 rows
# processed 506000 rows
# processed 507000 rows
# processed 508000 rows
# processed 509000 rows
# processed 510000 rows
# processed 511000 rows
# processed 512000 rows
# processed 513000 rows
# processed 514000 rows
# processed 515000 rows
# processed 516000 rows
# processed 517000 rows
# processed 518000 rows
# processed 519000 rows
# processed 520000 rows
# processed 521000 rows
# processed 522000 rows
# processed 523000 rows
# processed 524000 rows
# processed 525000 rows
# processed 526000 rows
# processed 527000 rows
# processed 528000 rows
# processed 529000 rows
# processed 530000 rows
# processed 531000 rows
# processed 532000 rows
# processed 533000 rows
# processed 534000 rows
# processed 535000 rows
# processed 536000 rows
# processed 537000 rows
# processed 538000 rows
# processed 539000 rows
# processed 540000 rows
# processed 541000 rows
# processed 542000 rows
# processed 543000 rows
# processed 544000 rows
# processed 545000 rows
# processed 546000 rows
# processed 547000 rows
# processed 548000 rows
# processed 549000 rows
# processed 550000 rows
# processed 551000 rows
# processed 552000 rows
# processed 553000 rows
# processed 554000 rows
# processed 555000 rows
# processed 556000 rows
# processed 557000 rows
# processed 558000 rows
# processed 559000 rows
# processed 560000 rows
# processed 561000 rows
# processed 562000 rows
# processed 563000 rows
# processed 564000 rows
# processed 565000 rows
# processed 566000 rows
# processed 567000 rows
# processed 568000 rows
# processed 569000 rows
# processed 570000 rows
# processed 571000 rows
# processed 572000 rows
# processed 573000 rows
# processed 574000 rows
# processed 575000 rows
# processed 576000 rows
# processed 577000 rows
# processed 578000 rows
# processed 579000 rows
# processed 580000 rows
# processed 581000 rows
# processed 582000 rows
# processed 583000 rows
# processed 584000 rows
# processed 585000 rows
# processed 586000 rows
# processed 587000 rows
# processed 588000 rows
# processed 589000 rows
# processed 590000 rows
# processed 591000 rows
# processed 592000 rows
# processed 593000 rows
# processed 594000 rows
# processed 595000 rows
# processed 596000 rows
# processed 597000 rows
# processed 598000 rows
# processed 599000 rows
# processed 600000 rows
# processed 601000 rows
# processed 602000 rows
# processed 603000 rows
# processed 604000 rows
# processed 605000 rows
# processed 606000 rows
# processed 607000 rows
# processed 608000 rows
# processed 609000 rows
# processed 610000 rows
# processed 611000 rows
# processed 612000 rows
# processed 613000 rows
# processed 614000 rows
# processed 615000 rows
# processed 616000 rows
# processed 617000 rows
# processed 618000 rows
# processed 619000 rows
# processed 620000 rows
# processed 621000 rows
# processed 622000 rows
# processed 623000 rows
# processed 624000 rows
# processed 625000 rows
# processed 626000 rows
# processed 627000 rows
# processed 628000 rows
# processed 629000 rows
# processed 630000 rows
# processed 631000 rows
# processed 632000 rows
# processed 633000 rows
# processed 634000 rows
# processed 635000 rows
# processed 636000 rows
# processed 637000 rows
# processed 638000 rows
# processed 639000 rows
# processed 640000 rows
# processed 641000 rows
# processed 642000 rows
# processed 643000 rows
# processed 644000 rows
# processed 645000 rows
# processed 646000 rows
# processed 647000 rows
# processed 648000 rows
# processed 649000 rows
# processed 650000 rows
# processed 651000 rows
# processed 652000 rows
# processed 653000 rows
# processed 654000 rows
# processed 655000 rows
# processed 656000 rows
# processed 657000 rows
# processed 658000 rows
# processed 659000 rows
# processed 660000 rows
# processed 661000 rows
# processed 662000 rows
# processed 663000 rows
# processed 664000 rows
# processed 665000 rows
# processed 666000 rows
# processed 667000 rows
# processed 668000 rows
# processed 669000 rows
# processed 670000 rows
# processed 671000 rows
# processed 672000 rows
# processed 673000 rows
# processed 674000 rows
# processed 675000 rows
# processed 676000 rows
# processed 677000 rows
# processed 678000 rows
# processed 679000 rows
# processed 680000 rows
# processed 681000 rows
# processed 682000 rows
# processed 683000 rows
# processed 684000 rows
# processed 685000 rows
# processed 686000 rows
# processed 687000 rows
# processed 688000 rows
# processed 689000 rows
# processed 690000 rows
# processed 691000 rows
# processed 692000 rows
# processed 693000 rows
# processed 694000 rows
# processed 695000 rows
# processed 696000 rows
# processed 697000 rows
# processed 698000 rows
# processed 699000 rows
# processed 700000 rows
# processed 701000 rows
# processed 702000 rows
# processed 703000 rows
# processed 704000 rows
# processed 705000 rows
# processed 706000 rows
# processed 707000 rows
# processed 708000 rows
# processed 709000 rows
# processed 710000 rows
# processed 711000 rows
# processed 712000 rows
# processed 713000 rows
# processed 714000 rows
# processed 715000 rows
# processed 716000 rows
# processed 717000 rows
# processed 718000 rows
# processed 719000 rows
# processed 720000 rows
# processed 721000 rows
# processed 722000 rows
# processed 723000 rows
# processed 724000 rows
# processed 725000 rows
# processed 726000 rows
# processed 727000 rows
# processed 728000 rows
# processed 729000 rows
# processed 730000 rows
# processed 731000 rows
# processed 732000 rows
# processed 733000 rows
# processed 734000 rows
# processed 735000 rows
# processed 736000 rows
# processed 737000 rows
# processed 738000 rows
# processed 739000 rows
# processed 740000 rows
# processed 741000 rows
# processed 742000 rows
# processed 743000 rows
# processed 744000 rows
# processed 745000 rows
# processed 746000 rows
# processed 747000 rows
# processed 748000 rows
# processed 749000 rows
# processed 750000 rows
# processed 751000 rows
# processed 752000 rows
# processed 753000 rows
# processed 754000 rows
# processed 755000 rows
# processed 756000 rows
# processed 757000 rows
# processed 758000 rows
# processed 759000 rows
# processed 760000 rows
# processed 761000 rows
# processed 762000 rows
# processed 763000 rows
# processed 764000 rows
# processed 765000 rows
# processed 766000 rows
# processed 767000 rows
# processed 768000 rows
# processed 769000 rows
# processed 770000 rows
# processed 771000 rows
# processed 772000 rows
# processed 773000 rows
# processed 774000 rows
# processed 775000 rows
# processed 776000 rows
# processed 777000 rows
# processed 778000 rows
# processed 779000 rows
# processed 780000 rows
# processed 781000 rows
# processed 782000 rows
# processed 783000 rows
# processed 784000 rows
# processed 785000 rows
# processed 786000 rows
# processed 787000 rows
# processed 788000 rows
# processed 789000 rows
# processed 790000 rows
# processed 791000 rows
# processed 792000 rows
# processed 793000 rows
# processed 794000 rows
# processed 795000 rows
# processed 796000 rows
# processed 797000 rows
# processed 798000 rows
# processed 799000 rows
# processed 800000 rows
# processed 801000 rows
# processed 802000 rows
# processed 803000 rows
# processed 804000 rows
# processed 805000 rows
# processed 806000 rows
# processed 807000 rows
# processed 808000 rows
# processed 809000 rows
# processed 810000 rows
# processed 811000 rows
# processed 812000 rows
# processed 813000 rows
# processed 814000 rows
# processed 815000 rows
# processed 816000 rows
# processed 817000 rows
# processed 818000 rows
# processed 819000 rows
# processed 820000 rows
# processed 821000 rows
# processed 822000 rows
# processed 823000 rows
# processed 824000 rows
# processed 825000 rows
# processed 826000 rows
# processed 827000 rows
# processed 828000 rows
# processed 829000 rows
# processed 830000 rows
# processed 831000 rows
# processed 832000 rows
# processed 833000 rows
# processed 834000 rows
# processed 835000 rows
# processed 836000 rows
# processed 837000 rows
# processed 838000 rows
# processed 839000 rows
# processed 840000 rows
# processed 841000 rows
# processed 842000 rows
# processed 843000 rows
# processed 844000 rows
# processed 845000 rows
# processed 846000 rows
# processed 847000 rows
# processed 848000 rows
# processed 849000 rows
# processed 850000 rows
# processed 851000 rows
# processed 852000 rows
# processed 853000 rows
# processed 854000 rows
# processed 855000 rows
# processed 856000 rows
# processed 857000 rows
# processed 858000 rows
# processed 859000 rows
# processed 860000 rows
# processed 861000 rows
# processed 862000 rows
# processed 863000 rows
# processed 864000 rows
# processed 865000 rows
# processed 866000 rows
# processed 867000 rows
# processed 868000 rows
# processed 869000 rows
# processed 870000 rows
# processed 871000 rows
# processed 872000 rows
# processed 873000 rows
# processed 874000 rows
# processed 875000 rows
# processed 876000 rows
# processed 877000 rows
# processed 878000 rows
# processed 879000 rows
# processed 880000 rows
# processed 881000 rows
# processed 882000 rows
# processed 883000 rows
# processed 884000 rows
# processed 885000 rows
# processed 886000 rows
# processed 887000 rows
# processed 888000 rows
# processed 889000 rows
# processed 890000 rows
# processed 891000 rows
# processed 892000 rows
# processed 893000 rows
# processed 894000 rows
# processed 895000 rows
# processed 896000 rows
# processed 897000 rows
# processed 898000 rows
# processed 899000 rows
# processed 900000 rows
# processed 901000 rows
# processed 902000 rows
# processed 903000 rows
# processed 904000 rows
# processed 905000 rows
# processed 906000 rows
# processed 907000 rows
# processed 908000 rows
# processed 909000 rows
# processed 910000 rows
# processed 911000 rows
# processed 912000 rows
# processed 913000 rows
# processed 914000 rows
# processed 915000 rows
# processed 916000 rows
# processed 917000 rows
# processed 918000 rows
# processed 919000 rows
# processed 920000 rows
# processed 921000 rows
# processed 922000 rows
# processed 923000 rows
# processed 924000 rows
# processed 925000 rows
# processed 926000 rows
# processed 927000 rows
# processed 928000 rows
# processed 929000 rows
# processed 930000 rows
# processed 931000 rows
# processed 932000 rows
# processed 933000 rows
# processed 934000 rows
# processed 935000 rows
# processed 936000 rows
# processed 937000 rows
# processed 938000 rows
# processed 939000 rows
# processed 940000 rows
# processed 941000 rows
# processed 942000 rows
# processed 943000 rows
# processed 944000 rows
# processed 945000 rows
# processed 946000 rows
# processed 947000 rows
# processed 948000 rows
# processed 949000 rows
# processed 950000 rows
# processed 951000 rows
# processed 952000 rows
# processed 953000 rows
# processed 954000 rows
# processed 955000 rows
# processed 956000 rows
# processed 957000 rows
# processed 958000 rows
# processed 959000 rows
# processed 960000 rows
# processed 961000 rows
# processed 962000 rows
# processed 963000 rows
# processed 964000 rows
# processed 965000 rows
# processed 966000 rows
# processed 967000 rows
# processed 968000 rows
# processed 969000 rows
# processed 970000 rows
# processed 971000 rows
# processed 972000 rows
# processed 973000 rows
# processed 974000 rows
# processed 975000 rows
# processed 976000 rows
# processed 977000 rows
# processed 978000 rows
# processed 979000 rows
# processed 980000 rows
# processed 981000 rows
# processed 982000 rows
# processed 983000 rows
# processed 984000 rows
# processed 985000 rows
# processed 986000 rows
# processed 987000 rows
# processed 988000 rows
# processed 989000 rows
# processed 990000 rows
# processed 991000 rows
# processed 992000 rows
# processed 993000 rows
# processed 994000 rows
# processed 995000 rows
# processed 996000 rows
# processed 997000 rows
# processed 998000 rows
# processed 999000 rows
# processed 1000000 rows
# processed 1001000 rows
# processed 1002000 rows
# processed 1003000 rows
# processed 1004000 rows
# processed 1005000 rows
# processed 1006000 rows
# processed 1007000 rows
# processed 1008000 rows
# processed 1009000 rows
# processed 1010000 rows
# processed 1011000 rows
# processed 1012000 rows
# processed 1013000 rows
# processed 1014000 rows
# processed 1015000 rows
# processed 1016000 rows
# processed 1017000 rows
# processed 1018000 rows
# processed 1019000 rows
# processed 1020000 rows
# processed 1021000 rows
# processed 1022000 rows
# processed 1023000 rows
# processed 1024000 rows
# processed 1025000 rows
# processed 1026000 rows
# processed 1027000 rows
# processed 1028000 rows
# processed 1029000 rows
# processed 1030000 rows
# processed 1031000 rows
# processed 1032000 rows
# processed 1033000 rows
# processed 1034000 rows
# processed 1035000 rows
# processed 1036000 rows
# processed 1037000 rows
# processed 1038000 rows
# processed 1039000 rows
# processed 1040000 rows
# processed 1041000 rows
# processed 1042000 rows
# processed 1043000 rows
# processed 1044000 rows
# processed 1045000 rows
# processed 1046000 rows
# processed 1047000 rows
# processed 1048000 rows
# processed 1049000 rows
# processed 1050000 rows
# processed 1051000 rows
# processed 1052000 rows
# processed 1053000 rows
# processed 1054000 rows
# processed 1055000 rows
# processed 1056000 rows
# processed 1057000 rows
# processed 1058000 rows
# processed 1059000 rows
# processed 1060000 rows
# processed 1061000 rows
# processed 1062000 rows
# processed 1063000 rows
# processed 1064000 rows
# processed 1065000 rows
# processed 1066000 rows
# processed 1067000 rows
# processed 1068000 rows
# processed 1069000 rows
# processed 1070000 rows
# processed 1071000 rows
# processed 1072000 rows
# processed 1073000 rows
# processed 1074000 rows
# processed 1075000 rows
# processed 1076000 rows
# processed 1077000 rows
# processed 1078000 rows
# processed 1079000 rows
# processed 1080000 rows
# processed 1081000 rows
# processed 1082000 rows
# processed 1083000 rows
# processed 1084000 rows
# processed 1085000 rows
# processed 1086000 rows
# processed 1087000 rows
# processed 1088000 rows
# processed 1089000 rows
# processed 1090000 rows
# processed 1091000 rows
# processed 1092000 rows
# processed 1093000 rows
# processed 1094000 rows
# processed 1095000 rows
# processed 1096000 rows
# processed 1097000 rows
# processed 1098000 rows
# processed 1099000 rows
# processed 1100000 rows
# processed 1101000 rows
# processed 1102000 rows
# processed 1103000 rows
# processed 1104000 rows
# processed 1105000 rows
# processed 1106000 rows
# processed 1107000 rows
# processed 1108000 rows
# processed 1109000 rows
# processed 1110000 rows
# processed 1111000 rows
# processed 1112000 rows
# processed 1113000 rows
# processed 1114000 rows
# processed 1115000 rows
# processed 1116000 rows
# processed 1117000 rows
# processed 1118000 rows
# processed 1119000 rows
# processed 1120000 rows
# processed 1121000 rows
# processed 1122000 rows
# processed 1123000 rows
# processed 1124000 rows
# processed 1125000 rows
# processed 1126000 rows
# processed 1127000 rows
# processed 1128000 rows
# processed 1129000 rows
# processed 1130000 rows
# processed 1131000 rows
# processed 1132000 rows
# processed 1133000 rows
# processed 1134000 rows
# processed 1135000 rows
# processed 1136000 rows
# processed 1137000 rows
# processed 1138000 rows
# processed 1139000 rows
# processed 1140000 rows
# processed 1141000 rows
# processed 1142000 rows
# processed 1143000 rows
# processed 1144000 rows
# processed 1145000 rows
# processed 1146000 rows
# processed 1147000 rows
# processed 1148000 rows
# processed 1149000 rows
# processed 1150000 rows
# processed 1151000 rows
# processed 1152000 rows
# processed 1153000 rows
# processed 1154000 rows
# processed 1155000 rows
# processed 1156000 rows
# processed 1157000 rows
# processed 1158000 rows
# processed 1159000 rows
# processed 1160000 rows
# processed 1161000 rows
# processed 1162000 rows
# processed 1163000 rows
# processed 1164000 rows
# processed 1165000 rows
# processed 1166000 rows
# processed 1167000 rows
# processed 1168000 rows
# processed 1169000 rows
# processed 1170000 rows
# processed 1171000 rows
# processed 1172000 rows
# processed 1173000 rows
# processed 1174000 rows
# processed 1175000 rows
# processed 1176000 rows
# processed 1177000 rows
# processed 1178000 rows
# processed 1179000 rows
# processed 1180000 rows
# processed 1181000 rows
# processed 1182000 rows
# processed 1183000 rows
# processed 1184000 rows
# processed 1185000 rows
# processed 1186000 rows
# processed 1187000 rows
# processed 1188000 rows
# processed 1189000 rows
# processed 1190000 rows
# processed 1191000 rows
# processed 1192000 rows
# processed 1193000 rows
# processed 1194000 rows
# processed 1195000 rows
# processed 1196000 rows
# processed 1197000 rows
# processed 1198000 rows
# processed 1199000 rows
# processed 1200000 rows
# processed 1201000 rows
# processed 1202000 rows
# processed 1203000 rows
# processed 1204000 rows
# processed 1205000 rows
# processed 1206000 rows
# processed 1207000 rows
# processed 1208000 rows
# processed 1209000 rows
# processed 1210000 rows
# processed 1211000 rows
# processed 1212000 rows
# processed 1213000 rows
# processed 1214000 rows
# processed 1215000 rows
# processed 1216000 rows
# processed 1217000 rows
# processed 1218000 rows
# processed 1219000 rows
# processed 1220000 rows
# processed 1221000 rows
# processed 1222000 rows
# processed 1223000 rows
# processed 1224000 rows
# processed 1225000 rows
# processed 1226000 rows
# processed 1227000 rows
# processed 1228000 rows
# processed 1229000 rows
# processed 1230000 rows
# processed 1231000 rows
# processed 1232000 rows
# processed 1233000 rows
# processed 1234000 rows
# processed 1235000 rows
# processed 1236000 rows
# processed 1237000 rows
# processed 1238000 rows
# processed 1239000 rows
# processed 1240000 rows
# processed 1241000 rows
# processed 1242000 rows
# processed 1243000 rows
# processed 1244000 rows
# processed 1245000 rows
# processed 1246000 rows
# processed 1247000 rows
# processed 1248000 rows
# processed 1249000 rows
# processed 1250000 rows
# processed 1251000 rows
# processed 1252000 rows
# processed 1253000 rows
# processed 1254000 rows
# processed 1255000 rows
# processed 1256000 rows
# processed 1257000 rows
# processed 1258000 rows
# processed 1259000 rows
# processed 1260000 rows
# processed 1261000 rows
# processed 1262000 rows
# processed 1263000 rows
# processed 1264000 rows
# processed 1265000 rows
# processed 1266000 rows
# processed 1267000 rows
# processed 1268000 rows
# processed 1269000 rows
# processed 1270000 rows
# processed 1271000 rows
# processed 1272000 rows
# processed 1273000 rows
# processed 1274000 rows
# processed 1275000 rows
# processed 1276000 rows
# processed 1277000 rows
# processed 1278000 rows
# processed 1279000 rows
# processed 1280000 rows
# processed 1281000 rows
# processed 1282000 rows
# processed 1283000 rows
# processed 1284000 rows
# processed 1285000 rows
# processed 1286000 rows
# processed 1287000 rows
# processed 1288000 rows
# processed 1289000 rows
# processed 1290000 rows
# processed 1291000 rows
# processed 1292000 rows
# processed 1293000 rows
# processed 1294000 rows
# processed 1295000 rows
# processed 1296000 rows
# processed 1297000 rows
# processed 1298000 rows
# processed 1299000 rows
# processed 1300000 rows
# processed 1301000 rows
# processed 1302000 rows
# processed 1303000 rows
# processed 1304000 rows
# processed 1305000 rows
# processed 1306000 rows
# processed 1307000 rows
# processed 1308000 rows
# processed 1309000 rows
# processed 1310000 rows
# processed 1311000 rows
# processed 1312000 rows
# processed 1313000 rows
# processed 1314000 rows
# processed 1315000 rows
# processed 1316000 rows
# processed 1317000 rows
# processed 1318000 rows
# processed 1319000 rows
# processed 1320000 rows
# processed 1321000 rows
# processed 1322000 rows
# processed 1323000 rows
# processed 1324000 rows
# processed 1325000 rows
# processed 1326000 rows
# processed 1327000 rows
# processed 1328000 rows
# processed 1329000 rows
# processed 1330000 rows
# processed 1331000 rows
# processed 1332000 rows
# processed 1333000 rows
# processed 1334000 rows
# processed 1335000 rows
# processed 1336000 rows
# processed 1337000 rows
# processed 1338000 rows
# processed 1339000 rows
# processed 1340000 rows
# processed 1341000 rows
# processed 1342000 rows
# processed 1343000 rows
# processed 1344000 rows
# processed 1345000 rows
# processed 1346000 rows
# processed 1347000 rows
# processed 1348000 rows
# processed 1349000 rows
# processed 1350000 rows
# processed 1351000 rows
# processed 1352000 rows
# processed 1353000 rows
# processed 1354000 rows
# processed 1355000 rows
# processed 1356000 rows
# processed 1357000 rows
# processed 1358000 rows
# processed 1359000 rows
# processed 1360000 rows
# processed 1361000 rows
# processed 1362000 rows
# processed 1363000 rows
# processed 1364000 rows
# processed 1365000 rows
# processed 1366000 rows
# processed 1367000 rows
# processed 1368000 rows
# processed 1369000 rows
# processed 1370000 rows
# processed 1371000 rows
# processed 1372000 rows
# processed 1373000 rows
# processed 1374000 rows
# processed 1375000 rows
# processed 1376000 rows
# processed 1377000 rows
# processed 1378000 rows
# processed 1379000 rows
# processed 1380000 rows
# processed 1381000 rows
# processed 1382000 rows
# processed 1383000 rows
# processed 1384000 rows
# processed 1385000 rows
# processed 1386000 rows
# processed 1387000 rows
# processed 1388000 rows
# processed 1389000 rows
# processed 1390000 rows
# processed 1391000 rows
# processed 1392000 rows
# processed 1393000 rows
# processed 1394000 rows
# processed 1395000 rows
# processed 1396000 rows
# processed 1397000 rows
# processed 1398000 rows
# processed 1399000 rows
# processed 1400000 rows
# processed 1401000 rows
# processed 1402000 rows
# processed 1403000 rows
# processed 1404000 rows
# processed 1405000 rows
# processed 1406000 rows
# processed 1407000 rows
# processed 1408000 rows
# processed 1409000 rows
# processed 1410000 rows
# processed 1411000 rows
# processed 1412000 rows
# processed 1413000 rows
# processed 1414000 rows
# processed 1415000 rows
# processed 1416000 rows
# processed 1417000 rows
# processed 1418000 rows
# processed 1419000 rows
# processed 1420000 rows
# processed 1421000 rows
# processed 1422000 rows
# processed 1423000 rows
# processed 1424000 rows
# processed 1425000 rows
# processed 1426000 rows
# processed 1427000 rows
# processed 1428000 rows
# processed 1429000 rows
# processed 1430000 rows
# processed 1431000 rows
# processed 1432000 rows
# processed 1433000 rows
# processed 1434000 rows
# processed 1435000 rows
# processed 1436000 rows
# processed 1437000 rows
# processed 1438000 rows
# processed 1439000 rows
# processed 1440000 rows
# processed 1441000 rows
# processed 1442000 rows
# processed 1443000 rows
# processed 1444000 rows
# processed 1445000 rows
# processed 1446000 rows
# processed 1447000 rows
# processed 1448000 rows
# processed 1449000 rows
# processed 1450000 rows
# processed 1451000 rows
# processed 1452000 rows
# processed 1453000 rows
# processed 1454000 rows
# processed 1455000 rows
# processed 1456000 rows
# processed 1457000 rows
# processed 1458000 rows
# processed 1459000 rows
# processed 1460000 rows
# processed 1461000 rows
# processed 1462000 rows
# processed 1463000 rows
# processed 1464000 rows
# processed 1465000 rows
# processed 1466000 rows
# processed 1467000 rows
# processed 1468000 rows
# processed 1469000 rows
# processed 1470000 rows
# processed 1471000 rows
# processed 1472000 rows
# processed 1473000 rows
# processed 1474000 rows
# processed 1475000 rows
# processed 1476000 rows
# processed 1477000 rows
# processed 1478000 rows
# processed 1479000 rows
# processed 1480000 rows
# processed 1481000 rows
# processed 1482000 rows
# processed 1483000 rows
# processed 1484000 rows
# processed 1485000 rows
# processed 1486000 rows
# processed 1487000 rows
# processed 1488000 rows
# processed 1489000 rows
# processed 1490000 rows
# processed 1491000 rows
# processed 1492000 rows
# processed 1493000 rows
# processed 1494000 rows
# processed 1495000 rows
# processed 1496000 rows
# processed 1497000 rows
# processed 1498000 rows
# processed 1499000 rows
# processed 1500000 rows
# processed 1501000 rows
# processed 1502000 rows
# processed 1503000 rows
# processed 1504000 rows
# processed 1505000 rows
# processed 1506000 rows
# processed 1507000 rows
# processed 1508000 rows
# processed 1509000 rows
# processed 1510000 rows
# processed 1511000 rows
# processed 1512000 rows
# processed 1513000 rows
# processed 1514000 rows
# processed 1515000 rows
# processed 1516000 rows
# processed 1517000 rows
# processed 1518000 rows
# processed 1519000 rows
# processed 1520000 rows
# processed 1521000 rows
# processed 1522000 rows
# processed 1523000 rows
# processed 1524000 rows
# processed 1525000 rows
# processed 1526000 rows
# processed 1527000 rows
# processed 1528000 rows
# processed 1529000 rows
# processed 1530000 rows
# processed 1531000 rows
# processed 1532000 rows
# processed 1533000 rows
# processed 1534000 rows
# processed 1535000 rows
# processed 1536000 rows
# processed 1537000 rows
# processed 1538000 rows
# processed 1539000 rows
# processed 1540000 rows
# processed 1541000 rows
# processed 1542000 rows
# processed 1543000 rows
# processed 1544000 rows
# processed 1545000 rows
# processed 1546000 rows
# processed 1547000 rows
# processed 1548000 rows
# processed 1549000 rows
# processed 1550000 rows
# processed 1551000 rows
# processed 1552000 rows
# processed 1553000 rows
# processed 1554000 rows
# processed 1555000 rows
# processed 1556000 rows
# processed 1557000 rows
# processed 1558000 rows
# processed 1559000 rows
# processed 1560000 rows
# processed 1561000 rows
# processed 1562000 rows
# processed 1563000 rows
# processed 1564000 rows
# processed 1565000 rows
# processed 1566000 rows
# processed 1567000 rows
# processed 1568000 rows
# processed 1569000 rows
# processed 1570000 rows
# processed 1571000 rows
# processed 1572000 rows
# processed 1573000 rows
# processed 1574000 rows
# processed 1575000 rows
# processed 1576000 rows
# processed 1577000 rows
# processed 1578000 rows
# processed 1579000 rows
# processed 1580000 rows
# processed 1581000 rows
# processed 1582000 rows
# processed 1583000 rows
# processed 1584000 rows
# processed 1585000 rows
# processed 1586000 rows
# processed 1587000 rows
# processed 1588000 rows
# processed 1589000 rows
# processed 1590000 rows
# processed 1591000 rows
# processed 1592000 rows
# processed 1593000 rows
# processed 1594000 rows
# processed 1595000 rows
# processed 1596000 rows
# processed 1597000 rows
# processed 1598000 rows
# processed 1599000 rows
# processed 1600000 rows
# processed 1601000 rows
# processed 1602000 rows
# processed 1603000 rows
# processed 1604000 rows
# processed 1605000 rows
# processed 1606000 rows
# processed 1607000 rows
# processed 1608000 rows
# processed 1609000 rows
# processed 1610000 rows
# processed 1611000 rows
# processed 1612000 rows
# processed 1613000 rows
# processed 1614000 rows
# processed 1615000 rows
# processed 1616000 rows
# processed 1617000 rows
# processed 1618000 rows
# processed 1619000 rows
# processed 1620000 rows
# processed 1621000 rows
# processed 1622000 rows
# processed 1623000 rows
# processed 1624000 rows
# processed 1625000 rows
# processed 1626000 rows
# processed 1627000 rows
# processed 1628000 rows
# processed 1629000 rows
# processed 1630000 rows
# processed 1631000 rows
# processed 1632000 rows
# processed 1633000 rows
# processed 1634000 rows
# processed 1635000 rows
# processed 1636000 rows
# processed 1637000 rows
# processed 1638000 rows
# processed 1639000 rows
# processed 1640000 rows
# processed 1641000 rows
# processed 1642000 rows
# processed 1643000 rows
# processed 1644000 rows
# processed 1645000 rows
# processed 1646000 rows
# processed 1647000 rows
# processed 1648000 rows
# processed 1649000 rows
# processed 1650000 rows
# processed 1651000 rows
# processed 1652000 rows
# processed 1653000 rows
# processed 1654000 rows
# processed 1655000 rows
# processed 1656000 rows
# processed 1657000 rows
# processed 1658000 rows
# processed 1659000 rows
# processed 1660000 rows
# processed 1661000 rows
# processed 1662000 rows
# processed 1663000 rows
# processed 1664000 rows
# processed 1665000 rows
# processed 1666000 rows
# processed 1667000 rows
# processed 1668000 rows
# processed 1669000 rows
# processed 1670000 rows
# processed 1671000 rows
# processed 1672000 rows
# processed 1673000 rows
# processed 1674000 rows
# processed 1675000 rows
# processed 1676000 rows
# processed 1677000 rows
# processed 1678000 rows
# processed 1679000 rows
# processed 1680000 rows
# processed 1681000 rows
# processed 1682000 rows
# processed 1683000 rows
# processed 1684000 rows
# processed 1685000 rows
# processed 1686000 rows
# processed 1687000 rows
# processed 1688000 rows
# processed 1689000 rows
# processed 1690000 rows
# processed 1691000 rows
# processed 1692000 rows
# processed 1693000 rows
# processed 1694000 rows
# processed 1695000 rows
# processed 1696000 rows
# processed 1697000 rows
# processed 1698000 rows
# processed 1699000 rows
# processed 1700000 rows
# processed 1701000 rows
# processed 1702000 rows
# processed 1703000 rows
# processed 1704000 rows
# processed 1705000 rows
# processed 1706000 rows
# processed 1707000 rows
# processed 1708000 rows
# processed 1709000 rows
# processed 1710000 rows
# processed 1711000 rows
# processed 1712000 rows
# processed 1713000 rows
# processed 1714000 rows
# processed 1715000 rows
# processed 1716000 rows
# processed 1717000 rows
# processed 1718000 rows
# processed 1719000 rows
# processed 1720000 rows
# processed 1721000 rows
# processed 1722000 rows
# processed 1723000 rows
# processed 1724000 rows
# processed 1725000 rows
# processed 1726000 rows
# processed 1727000 rows
# processed 1728000 rows
# processed 1729000 rows
# processed 1730000 rows
# processed 1731000 rows
# processed 1732000 rows
# processed 1733000 rows
# processed 1734000 rows
# processed 1735000 rows
# processed 1736000 rows
# processed 1737000 rows
# processed 1738000 rows
# processed 1739000 rows
# processed 1740000 rows
# processed 1741000 rows
# processed 1742000 rows
# processed 1743000 rows
# processed 1744000 rows
# processed 1745000 rows
# processed 1746000 rows
# processed 1747000 rows
# processed 1748000 rows
# processed 1749000 rows
# processed 1750000 rows
# processed 1751000 rows
# processed 1752000 rows
# processed 1753000 rows
# processed 1754000 rows
# processed 1755000 rows
# processed 1756000 rows
# processed 1757000 rows
# processed 1758000 rows
# processed 1759000 rows
# processed 1760000 rows
# processed 1761000 rows
# processed 1762000 rows
# processed 1763000 rows
# processed 1764000 rows
# processed 1765000 rows
# processed 1766000 rows
# processed 1767000 rows
# processed 1768000 rows
# processed 1769000 rows
# processed 1770000 rows
# processed 1771000 rows
# processed 1772000 rows
# processed 1773000 rows
# processed 1774000 rows
# processed 1775000 rows
# processed 1776000 rows
# processed 1777000 rows
# processed 1778000 rows
# processed 1779000 rows
# processed 1780000 rows
# processed 1781000 rows
# processed 1782000 rows
# processed 1783000 rows
# processed 1784000 rows
# processed 1785000 rows
# processed 1786000 rows
# processed 1787000 rows
# processed 1788000 rows
# processed 1789000 rows
# processed 1790000 rows
# processed 1791000 rows
# processed 1792000 rows
# processed 1793000 rows
# processed 1794000 rows
# processed 1795000 rows
# processed 1796000 rows
# processed 1797000 rows
# processed 1798000 rows
# processed 1799000 rows
# processed 1800000 rows
# processed 1801000 rows
# processed 1802000 rows
# processed 1803000 rows
# processed 1804000 rows
# processed 1805000 rows
# processed 1806000 rows
# processed 1807000 rows
# processed 1808000 rows
# processed 1809000 rows
# processed 1810000 rows
# processed 1811000 rows
# processed 1812000 rows
# processed 1813000 rows
# processed 1814000 rows
# processed 1815000 rows
# processed 1816000 rows
# processed 1817000 rows
# processed 1818000 rows
# processed 1819000 rows
# processed 1820000 rows
# processed 1821000 rows
# processed 1822000 rows
# processed 1823000 rows
# processed 1824000 rows
# processed 1825000 rows
# processed 1826000 rows
# processed 1827000 rows
# processed 1828000 rows
# processed 1829000 rows
# processed 1830000 rows
# processed 1831000 rows
# processed 1832000 rows
# processed 1833000 rows
# processed 1834000 rows
# processed 1835000 rows
# processed 1836000 rows
# processed 1837000 rows
# processed 1838000 rows
# processed 1839000 rows
# processed 1840000 rows
# processed 1841000 rows
# processed 1842000 rows
# processed 1843000 rows
# processed 1844000 rows
# processed 1845000 rows
# processed 1846000 rows
# processed 1847000 rows
# processed 1848000 rows
# processed 1849000 rows
# processed 1850000 rows
# processed 1851000 rows
# processed 1852000 rows
# processed 1853000 rows
# processed 1854000 rows
# processed 1855000 rows
# processed 1856000 rows
# processed 1857000 rows
# processed 1858000 rows
# processed 1859000 rows
# processed 1860000 rows
# processed 1861000 rows
# processed 1862000 rows
# processed 1863000 rows
# processed 1864000 rows
# processed 1865000 rows
# processed 1866000 rows
# processed 1867000 rows
# processed 1868000 rows
# processed 1869000 rows
# processed 1870000 rows
# processed 1871000 rows
# processed 1872000 rows
# processed 1873000 rows
# processed 1874000 rows
# processed 1875000 rows
# processed 1876000 rows
# processed 1877000 rows
# processed 1878000 rows
# processed 1879000 rows
# processed 1880000 rows
# processed 1881000 rows
# processed 1882000 rows
# processed 1883000 rows
# processed 1884000 rows
# processed 1885000 rows
# processed 1886000 rows
# processed 1887000 rows
# processed 1888000 rows
# processed 1889000 rows
# processed 1890000 rows
# processed 1891000 rows
# processed 1892000 rows
# processed 1893000 rows
# processed 1894000 rows
# processed 1895000 rows
# processed 1896000 rows
# processed 1897000 rows
# processed 1898000 rows
# processed 1899000 rows
# processed 1900000 rows
# processed 1901000 rows
# processed 1902000 rows
# processed 1903000 rows
# processed 1904000 rows
# processed 1905000 rows
# processed 1906000 rows
# processed 1907000 rows
# processed 1908000 rows
# processed 1909000 rows
# processed 1910000 rows
# processed 1911000 rows
# processed 1912000 rows
# processed 1913000 rows
# processed 1914000 rows
# processed 1915000 rows
# processed 1916000 rows
# processed 1917000 rows
# processed 1918000 rows
# processed 1919000 rows
# processed 1920000 rows
# processed 1921000 rows
# processed 1922000 rows
# processed 1923000 rows
# processed 1924000 rows
# processed 1925000 rows
# processed 1926000 rows
# processed 1927000 rows
# processed 1928000 rows
# processed 1929000 rows
# processed 1930000 rows
# processed 1931000 rows
# processed 1932000 rows
# processed 1933000 rows
# processed 1934000 rows
# processed 1935000 rows
# processed 1936000 rows
# processed 1937000 rows
# processed 1938000 rows
# processed 1939000 rows
# processed 1940000 rows
# processed 1941000 rows
# processed 1942000 rows
# processed 1943000 rows
# processed 1944000 rows
# processed 1945000 rows
# processed 1946000 rows
# processed 1947000 rows
# processed 1948000 rows
# processed 1949000 rows
# processed 1950000 rows
# processed 1951000 rows
# processed 1952000 rows
# processed 1953000 rows
# processed 1954000 rows
# processed 1955000 rows
# processed 1956000 rows
# processed 1957000 rows
# processed 1958000 rows
# processed 1959000 rows
# processed 1960000 rows
# processed 1961000 rows
# processed 1962000 rows
# processed 1963000 rows
# processed 1964000 rows
# processed 1965000 rows
# processed 1966000 rows
# processed 1967000 rows
# processed 1968000 rows
# processed 1969000 rows
# processed 1970000 rows
# processed 1971000 rows
# processed 1972000 rows
# processed 1973000 rows
# processed 1974000 rows
# processed 1975000 rows
# processed 1976000 rows
# processed 1977000 rows
# processed 1978000 rows
# processed 1979000 rows
# processed 1980000 rows
# processed 1981000 rows
# processed 1982000 rows
# processed 1983000 rows
# processed 1984000 rows
# processed 1985000 rows
# processed 1986000 rows
# processed 1987000 rows
# processed 1988000 rows
# processed 1989000 rows
# processed 1990000 rows
# processed 1991000 rows
# processed 1992000 rows
# processed 1993000 rows
# processed 1994000 rows
# processed 1995000 rows
# processed 1996000 rows
# processed 1997000 rows
# processed 1998000 rows
# processed 1999000 rows
# processed 2000000 rows
# processed 2001000 rows
# processed 2002000 rows
# processed 2003000 rows
# processed 2004000 rows
# processed 2005000 rows
# processed 2006000 rows
# processed 2007000 rows
# processed 2008000 rows
# processed 2009000 rows
# processed 2010000 rows
# processed 2011000 rows
# processed 2012000 rows
# processed 2013000 rows
# processed 2014000 rows
# processed 2015000 rows
# processed 2016000 rows
# processed 2017000 rows
# processed 2018000 rows
# processed 2019000 rows
# processed 2020000 rows
# processed 2021000 rows
# processed 2022000 rows
# processed 2023000 rows
# processed 2024000 rows
# processed 2025000 rows
# processed 2026000 rows
# processed 2027000 rows
# processed 2028000 rows
# processed 2029000 rows
# processed 2030000 rows
# processed 2031000 rows
# processed 2032000 rows
# processed 2033000 rows
# processed 2034000 rows
# processed 2035000 rows
# processed 2036000 rows
# processed 2037000 rows
# processed 2038000 rows
# processed 2039000 rows
# processed 2040000 rows
# processed 2041000 rows
# processed 2042000 rows
# processed 2043000 rows
# processed 2044000 rows
# processed 2045000 rows
# processed 2046000 rows
# processed 2047000 rows
# processed 2048000 rows
# processed 2049000 rows
# processed 2050000 rows
# processed 2051000 rows
# processed 2052000 rows
# processed 2053000 rows
# processed 2054000 rows
# processed 2055000 rows
# processed 2056000 rows
# processed 2057000 rows
# processed 2058000 rows
# processed 2059000 rows
# processed 2060000 rows
# processed 2061000 rows
# processed 2062000 rows
# processed 2063000 rows
# processed 2064000 rows
# processed 2065000 rows
# processed 2066000 rows
# processed 2067000 rows
# processed 2068000 rows
# processed 2069000 rows
# processed 2070000 rows
# processed 2071000 rows
# processed 2072000 rows
# processed 2073000 rows
# processed 2074000 rows
# processed 2075000 rows
# processed 2076000 rows
# processed 2077000 rows
# processed 2078000 rows
# processed 2079000 rows
# processed 2080000 rows
# processed 2081000 rows
# processed 2082000 rows
# processed 2083000 rows
# processed 2084000 rows
# processed 2085000 rows
# processed 2086000 rows
# processed 2087000 rows
# processed 2088000 rows
# processed 2089000 rows
# processed 2090000 rows
# processed 2091000 rows
# processed 2092000 rows
# processed 2093000 rows
# processed 2094000 rows
# processed 2095000 rows
# processed 2096000 rows
# processed 2097000 rows
# processed 2098000 rows
# processed 2099000 rows
# processed 2100000 rows
# processed 2101000 rows
# processed 2102000 rows
# processed 2103000 rows
# processed 2104000 rows
# processed 2105000 rows
# processed 2106000 rows
# processed 2107000 rows
# processed 2108000 rows
# processed 2109000 rows
# processed 2110000 rows
# processed 2111000 rows
# processed 2112000 rows
# processed 2113000 rows
# processed 2114000 rows
# processed 2115000 rows
# processed 2116000 rows
# processed 2117000 rows
# processed 2118000 rows
# processed 2119000 rows
# processed 2120000 rows
# processed 2121000 rows
# processed 2122000 rows
# processed 2123000 rows
# processed 2124000 rows
# processed 2125000 rows
# processed 2126000 rows
# processed 2127000 rows
# processed 2128000 rows
# processed 2129000 rows
# processed 2130000 rows
# processed 2131000 rows
# processed 2132000 rows
# processed 2133000 rows
# processed 2134000 rows
# processed 2135000 rows
# ...
# processed 6994000 rows
# processed 6995000 rows
# processed 6996000 rows
# processed 6997000 rows
# processed 6998000 rows
# processed 6999000 rows
# processed 7000000 rows
# processed 7001000 rows
# processed 7002000 rows
# processed 7003000 rows
# processed 7004000 rows
# processed 7005000 rows
# processed 7006000 rows
# processed 7007000 rows
# processed 7008000 rows
# processed 7009000 rows
# processed 7010000 rows
# processed 7011000 rows
# processed 7012000 rows
# processed 7013000 rows
# processed 7014000 rows
# processed 7015000 rows
# processed 7016000 rows
# processed 7017000 rows
# processed 7018000 rows
# processed 7019000 rows
# processed 7020000 rows
# processed 7021000 rows
# processed 7022000 rows
# processed 7023000 rows
# processed 7024000 rows
# processed 7025000 rows
# processed 7026000 rows
# processed 7027000 rows
# processed 7028000 rows
# processed 7029000 rows
# processed 7030000 rows
# processed 7031000 rows
# processed 7032000 rows
# processed 7033000 rows
# processed 7034000 rows
# processed 7035000 rows
# processed 7036000 rows
# processed 7037000 rows
# processed 7038000 rows
# processed 7039000 rows
# processed 7040000 rows
# processed 7041000 rows
# processed 7042000 rows
# processed 7043000 rows
# processed 7044000 rows
# processed 7045000 rows
# processed 7046000 rows
# processed 7047000 rows
# processed 7048000 rows
# processed 7049000 rows
# processed 7050000 rows
# processed 7051000 rows
# processed 7052000 rows
# processed 7053000 rows
# processed 7054000 rows
# processed 7055000 rows
# processed 7056000 rows
# processed 7057000 rows
# processed 7058000 rows
# processed 7059000 rows
# processed 7060000 rows
# processed 7061000 rows
# processed 7062000 rows
# processed 7063000 rows
# processed 7064000 rows
# processed 7065000 rows
# processed 7066000 rows
# processed 7067000 rows
# processed 7068000 rows
# processed 7069000 rows
# processed 7070000 rows
# processed 7071000 rows
# processed 7072000 rows
# processed 7073000 rows
# processed 7074000 rows
# processed 7075000 rows
# processed 7076000 rows
# processed 7077000 rows
# processed 7078000 rows
# processed 7079000 rows
# processed 7080000 rows
# processed 7081000 rows
# processed 7082000 rows
# processed 7083000 rows
# processed 7084000 rows
# processed 7085000 rows
# processed 7086000 rows
# processed 7087000 rows
# processed 7088000 rows
# processed 7089000 rows
# processed 7090000 rows
# processed 7091000 rows
# processed 7092000 rows
# processed 7093000 rows
# processed 7094000 rows
# processed 7095000 rows
# processed 7096000 rows
# processed 7097000 rows
# processed 7098000 rows
# processed 7099000 rows
# processed 7100000 rows
# processed 7101000 rows
# processed 7102000 rows
# processed 7103000 rows
# processed 7104000 rows
# processed 7105000 rows
# processed 7106000 rows
# processed 7107000 rows
# processed 7108000 rows
# processed 7109000 rows
# processed 7110000 rows
# processed 7111000 rows
# processed 7112000 rows
# processed 7113000 rows
# processed 7114000 rows
# processed 7115000 rows
# processed 7116000 rows
# processed 7117000 rows
# processed 7118000 rows
# processed 7119000 rows
# processed 7120000 rows
# processed 7121000 rows
# processed 7122000 rows
# processed 7123000 rows
# processed 7124000 rows
# processed 7125000 rows
# processed 7126000 rows
# processed 7127000 rows
# processed 7128000 rows
# processed 7129000 rows
# processed 7130000 rows
# processed 7131000 rows
# processed 7132000 rows
# processed 7133000 rows
# processed 7134000 rows
# processed 7135000 rows
# processed 7136000 rows
# processed 7137000 rows
# processed 7138000 rows
# processed 7139000 rows
# processed 7140000 rows
# processed 7141000 rows
# processed 7142000 rows
# processed 7143000 rows
# processed 7144000 rows
# processed 7145000 rows
# processed 7146000 rows
# processed 7147000 rows
# processed 7148000 rows
# processed 7149000 rows
# processed 7150000 rows
# processed 7151000 rows
# processed 7152000 rows
# processed 7153000 rows
# processed 7154000 rows
# processed 7155000 rows
# processed 7156000 rows
# processed 7157000 rows
# processed 7158000 rows
# processed 7159000 rows
# processed 7160000 rows
# processed 7161000 rows
# processed 7162000 rows
# processed 7163000 rows
# processed 7164000 rows
# processed 7165000 rows
# processed 7166000 rows
# processed 7167000 rows
# processed 7168000 rows
# processed 7169000 rows
# processed 7170000 rows
# processed 7171000 rows
# processed 7172000 rows
# processed 7173000 rows
# processed 7174000 rows
# processed 7175000 rows
# processed 7176000 rows
# processed 7177000 rows
# processed 7178000 rows
# processed 7179000 rows
# processed 7180000 rows
# processed 7181000 rows
# processed 7182000 rows
# processed 7183000 rows
# processed 7184000 rows
# processed 7185000 rows
# processed 7186000 rows
# processed 7187000 rows
# processed 7188000 rows
# processed 7189000 rows
# processed 7190000 rows
# processed 7191000 rows
# processed 7192000 rows
# processed 7193000 rows
# processed 7194000 rows
# processed 7195000 rows
# processed 7196000 rows
# processed 7197000 rows
# processed 7198000 rows
# processed 7199000 rows
# processed 7200000 rows
# processed 7201000 rows
# processed 7202000 rows
# processed 7203000 rows
# processed 7204000 rows
# processed 7205000 rows
# processed 7206000 rows
# processed 7207000 rows
# processed 7208000 rows
# processed 7209000 rows
# processed 7210000 rows
# processed 7211000 rows
# processed 7212000 rows
# processed 7213000 rows
# processed 7214000 rows
# processed 7215000 rows
# processed 7216000 rows
# processed 7217000 rows
# processed 7218000 rows
# processed 7219000 rows
# processed 7220000 rows
# processed 7221000 rows
# processed 7222000 rows
# processed 7223000 rows
# processed 7224000 rows
# processed 7225000 rows
# processed 7226000 rows
# processed 7227000 rows
# processed 7228000 rows
# processed 7229000 rows
# processed 7230000 rows
# processed 7231000 rows
# processed 7232000 rows
# processed 7233000 rows
# processed 7234000 rows
# processed 7235000 rows
# processed 7236000 rows
# processed 7237000 rows
# processed 7238000 rows
# processed 7239000 rows
# processed 7240000 rows
# processed 7241000 rows
# processed 7242000 rows
# processed 7243000 rows
# processed 7244000 rows
# processed 7245000 rows
# processed 7246000 rows
# processed 7247000 rows
# processed 7248000 rows
# processed 7249000 rows
# processed 7250000 rows
# processed 7251000 rows
# processed 7252000 rows
# processed 7253000 rows
# processed 7254000 rows
# processed 7255000 rows
# processed 7256000 rows
# processed 7257000 rows
# processed 7258000 rows
# processed 7259000 rows
# processed 7260000 rows
# processed 7261000 rows
# processed 7262000 rows
# processed 7263000 rows
# processed 7264000 rows
# processed 7265000 rows
# processed 7266000 rows
# processed 7267000 rows
# processed 7268000 rows
# processed 7269000 rows
# processed 7270000 rows
# processed 7271000 rows
# processed 7272000 rows
# processed 7273000 rows
# processed 7274000 rows
# processed 7275000 rows
# processed 7276000 rows
# processed 7277000 rows
# processed 7278000 rows
# processed 7279000 rows
# processed 7280000 rows
# processed 7281000 rows
# processed 7282000 rows
# processed 7283000 rows
# processed 7284000 rows
# processed 7285000 rows
# processed 7286000 rows
# processed 7287000 rows
# processed 7288000 rows
# processed 7289000 rows
# processed 7290000 rows
# processed 7291000 rows
# processed 7292000 rows
# processed 7293000 rows
# processed 7294000 rows
# processed 7295000 rows
# processed 7296000 rows
# processed 7297000 rows
# processed 7298000 rows
# processed 7299000 rows
# processed 7300000 rows
# processed 7301000 rows
# processed 7302000 rows
# processed 7303000 rows
# processed 7304000 rows
# processed 7305000 rows
# processed 7306000 rows
# processed 7307000 rows
# processed 7308000 rows
# processed 7309000 rows
# processed 7310000 rows
# processed 7311000 rows
# processed 7312000 rows
# processed 7313000 rows
# processed 7314000 rows
# processed 7315000 rows
# processed 7316000 rows
# processed 7317000 rows
# processed 7318000 rows
# processed 7319000 rows
# processed 7320000 rows
# processed 7321000 rows
# processed 7322000 rows
# processed 7323000 rows
# processed 7324000 rows
# processed 7325000 rows
# processed 7326000 rows
# processed 7327000 rows
# processed 7328000 rows
# processed 7329000 rows
# processed 7330000 rows
# processed 7331000 rows
# processed 7332000 rows
# processed 7333000 rows
# processed 7334000 rows
# processed 7335000 rows
# processed 7336000 rows
# processed 7337000 rows
# processed 7338000 rows
# processed 7339000 rows
# processed 7340000 rows
# processed 7341000 rows
# processed 7342000 rows
# processed 7343000 rows
# processed 7344000 rows
# processed 7345000 rows
# processed 7346000 rows
# processed 7347000 rows
# processed 7348000 rows
# processed 7349000 rows
# processed 7350000 rows
# processed 7351000 rows
# processed 7352000 rows
# processed 7353000 rows
# processed 7354000 rows
# processed 7355000 rows
# processed 7356000 rows
# processed 7357000 rows
# processed 7358000 rows
# processed 7359000 rows
# processed 7360000 rows
# processed 7361000 rows
# processed 7362000 rows
# processed 7363000 rows
# processed 7364000 rows
# processed 7365000 rows
# processed 7366000 rows
# processed 7367000 rows
# processed 7368000 rows
# processed 7369000 rows
# processed 7370000 rows
# processed 7371000 rows
# processed 7372000 rows
# processed 7373000 rows
# processed 7374000 rows
# processed 7375000 rows
# processed 7376000 rows
# processed 7377000 rows
# processed 7378000 rows
# processed 7379000 rows
# processed 7380000 rows
# processed 7381000 rows
# processed 7382000 rows
# processed 7383000 rows
# processed 7384000 rows
# processed 7385000 rows
# processed 7386000 rows
# processed 7387000 rows
# processed 7388000 rows
# processed 7389000 rows
# processed 7390000 rows
# processed 7391000 rows
# processed 7392000 rows
# processed 7393000 rows
# processed 7394000 rows
# processed 7395000 rows
# processed 7396000 rows
# processed 7397000 rows
# processed 7398000 rows
# processed 7399000 rows
# processed 7400000 rows
# processed 7401000 rows
# processed 7402000 rows
# processed 7403000 rows
# processed 7404000 rows
# processed 7405000 rows
# processed 7406000 rows
# processed 7407000 rows
# processed 7408000 rows
# processed 7409000 rows
# processed 7410000 rows
# processed 7411000 rows
# processed 7412000 rows
# processed 7413000 rows
# processed 7414000 rows
# processed 7415000 rows
# processed 7416000 rows
# processed 7417000 rows
# processed 7418000 rows
# processed 7419000 rows
# processed 7420000 rows
# processed 7421000 rows
# processed 7422000 rows
# processed 7423000 rows
# processed 7424000 rows
# processed 7425000 rows
# processed 7426000 rows
# processed 7427000 rows
# processed 7428000 rows
# processed 7429000 rows
# processed 7430000 rows
# processed 7431000 rows
# processed 7432000 rows
# processed 7433000 rows
# processed 7434000 rows
# processed 7435000 rows
# processed 7436000 rows
# processed 7437000 rows
# processed 7438000 rows
# processed 7439000 rows
# processed 7440000 rows
# processed 7441000 rows
# processed 7442000 rows
# processed 7443000 rows
# processed 7444000 rows
# processed 7445000 rows
# processed 7446000 rows
# processed 7447000 rows
# processed 7448000 rows
# processed 7449000 rows
# processed 7450000 rows
# processed 7451000 rows
# processed 7452000 rows
# processed 7453000 rows
# processed 7454000 rows
# processed 7455000 rows
# processed 7456000 rows
# processed 7457000 rows
# processed 7458000 rows
# processed 7459000 rows
# processed 7460000 rows
# processed 7461000 rows
# processed 7462000 rows
# processed 7463000 rows
# processed 7464000 rows
# processed 7465000 rows
# processed 7466000 rows
# processed 7467000 rows
# processed 7468000 rows
# processed 7469000 rows
# processed 7470000 rows
# processed 7471000 rows
# processed 7472000 rows
# processed 7473000 rows
# processed 7474000 rows
# processed 7475000 rows
# processed 7476000 rows
# processed 7477000 rows
# processed 7478000 rows
# processed 7479000 rows
# processed 7480000 rows
# processed 7481000 rows
# processed 7482000 rows
# processed 7483000 rows
# processed 7484000 rows
# processed 7485000 rows
# processed 7486000 rows
# processed 7487000 rows
# processed 7488000 rows
# processed 7489000 rows
# processed 7490000 rows
# processed 7491000 rows
# processed 7492000 rows
# processed 7493000 rows
# processed 7494000 rows
# processed 7495000 rows
# processed 7496000 rows
# processed 7497000 rows
# processed 7498000 rows
# processed 7499000 rows
# processed 7500000 rows
# processed 7501000 rows
# processed 7502000 rows
# processed 7503000 rows
# processed 7504000 rows
# processed 7505000 rows
# processed 7506000 rows
# processed 7507000 rows
# processed 7508000 rows
# processed 7509000 rows
# processed 7510000 rows
# processed 7511000 rows
# processed 7512000 rows
# processed 7513000 rows
# processed 7514000 rows
# processed 7515000 rows
# processed 7516000 rows
# processed 7517000 rows
# processed 7518000 rows
# processed 7519000 rows
# processed 7520000 rows
# processed 7521000 rows
# processed 7522000 rows
# processed 7523000 rows
# processed 7524000 rows
# processed 7525000 rows
# processed 7526000 rows
# processed 7527000 rows
# processed 7528000 rows
# processed 7529000 rows
# processed 7530000 rows
# processed 7531000 rows
# processed 7532000 rows
# processed 7533000 rows
# processed 7534000 rows
# processed 7535000 rows
# processed 7536000 rows
# processed 7537000 rows
# processed 7538000 rows
# processed 7539000 rows
# processed 7540000 rows
# processed 7541000 rows
# processed 7542000 rows
# processed 7543000 rows
# processed 7544000 rows
# processed 7545000 rows
# processed 7546000 rows
# processed 7547000 rows
# processed 7548000 rows
# processed 7549000 rows
# processed 7550000 rows
# processed 7551000 rows
# processed 7552000 rows
# processed 7553000 rows
# processed 7554000 rows
# processed 7555000 rows
# processed 7556000 rows
# processed 7557000 rows
# processed 7558000 rows
# processed 7559000 rows
# processed 7560000 rows
# processed 7561000 rows
# processed 7562000 rows
# processed 7563000 rows
# processed 7564000 rows
# processed 7565000 rows
# processed 7566000 rows
# processed 7567000 rows
# processed 7568000 rows
# processed 7569000 rows
# processed 7570000 rows
# processed 7571000 rows
# processed 7572000 rows
# processed 7573000 rows
# processed 7574000 rows
# processed 7575000 rows
# processed 7576000 rows
# processed 7577000 rows
# processed 7578000 rows
# processed 7579000 rows
# processed 7580000 rows
# processed 7581000 rows
# processed 7582000 rows
# processed 7583000 rows
# processed 7584000 rows
# processed 7585000 rows
# processed 7586000 rows
# processed 7587000 rows
# processed 7588000 rows
# processed 7589000 rows
# processed 7590000 rows
# processed 7591000 rows
# processed 7592000 rows
# processed 7593000 rows
# processed 7594000 rows
# processed 7595000 rows
# processed 7596000 rows
# processed 7597000 rows
# processed 7598000 rows
# processed 7599000 rows
# processed 7600000 rows
# processed 7601000 rows
# processed 7602000 rows
# processed 7603000 rows
# processed 7604000 rows
# processed 7605000 rows
# processed 7606000 rows
# processed 7607000 rows
# processed 7608000 rows
# processed 7609000 rows
# processed 7610000 rows
# processed 7611000 rows
# processed 7612000 rows
# processed 7613000 rows
# processed 7614000 rows
# processed 7615000 rows
# processed 7616000 rows
# processed 7617000 rows
# processed 7618000 rows
# processed 7619000 rows
# processed 7620000 rows
# processed 7621000 rows
# processed 7622000 rows
# processed 7623000 rows
# processed 7624000 rows
# processed 7625000 rows
# processed 7626000 rows
# processed 7627000 rows
# processed 7628000 rows
# processed 7629000 rows
# processed 7630000 rows
# processed 7631000 rows
# processed 7632000 rows
# processed 7633000 rows
# processed 7634000 rows
# processed 7635000 rows
# processed 7636000 rows
# processed 7637000 rows
# processed 7638000 rows
# processed 7639000 rows
# processed 7640000 rows
# processed 7641000 rows
# processed 7642000 rows
# processed 7643000 rows
# processed 7644000 rows
# processed 7645000 rows
# processed 7646000 rows
# processed 7647000 rows
# processed 7648000 rows
# processed 7649000 rows
# processed 7650000 rows
# processed 7651000 rows
# processed 7652000 rows
# processed 7653000 rows
# processed 7654000 rows
# processed 7655000 rows
# processed 7656000 rows
# processed 7657000 rows
# processed 7658000 rows
# processed 7659000 rows
# processed 7660000 rows
# processed 7661000 rows
# processed 7662000 rows
# processed 7663000 rows
# processed 7664000 rows
# processed 7665000 rows
# processed 7666000 rows
# processed 7667000 rows
# processed 7668000 rows
# processed 7669000 rows
# processed 7670000 rows
# processed 7671000 rows
# processed 7672000 rows
# processed 7673000 rows
# processed 7674000 rows
# processed 7675000 rows
# processed 7676000 rows
# processed 7677000 rows
# processed 7678000 rows
# processed 7679000 rows
# processed 7680000 rows
# processed 7681000 rows
# processed 7682000 rows
# processed 7683000 rows
# processed 7684000 rows
# processed 7685000 rows
# processed 7686000 rows
# processed 7687000 rows
# processed 7688000 rows
