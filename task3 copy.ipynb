# %%
import pandas as pd

# %%
hdf_file = pd.HDFStore('fakenews_data.h5', 'w')
hdf_file.close()

# %%
labels = ['fake', 'junksci', 'bias', 'unknown', 'conspiracy',
       'political', 'unreliable', 'hate', 'clickbait', 'reliable',
       'rumor', 'satire']

# %%
hdf_file = pd.HDFStore('fakenews_data.h5', 'a')
df = pd.read_csv('E:/ML/fake_news_data/news.csv/news_cleaned_2018_02_13.csv', chunksize=1000, index_col=0, lineterminator='\n')

# %%
for chunk in df:
    hdf_file.put('data', chunk, format='table', data_columns=True, append=True)
    break
hdf_file.flush()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 for chunk in df:
# ----> 2     hdf_file.put('data', chunk, format='table', data_columns=True, append=True)
#       3     break
#       4 hdf_file.flush()
#
# File d:\Programmer\anaconda_3\envs\fakeNewsProject\lib\site-packages\pandas\io\pytables.py:1123, in HDFStore.put(self, key, value, format, index, append, complib, complevel, min_itemsize, nan_rep, data_columns, encoding, errors, track_times, dropna)
#    1121     format = get_option("io.hdf.default_format") or "fixed"
#    1122 format = self._validate_format(format)
# -> 1123 self._write_to_group(
#    1124     key,
#    1125     value,
#    1126     format=format,
#    1127     index=index,
#    1128     append=append,
#    1129     complib=complib,
#    1130     complevel=complevel,
#    1131     min_itemsize=min_itemsize,
# ...

# %%
hdf_file.get('data').head()
# Out:
#         id                     domain        type  \
# 1000  1137          beforeitsnews.com        fake
# 1001  1138          beforeitsnews.com        fake
# 1002  1140           awarenessact.com  conspiracy
# 1003  1141       bipartisanreport.com   clickbait
# 1004  1142  familysecuritymatters.org  conspiracy
#
#                                                     url  \
# 1000  http://beforeitsnews.com/science-and-technolog...
# 1001  http://beforeitsnews.com/opinion/2018/01/poten...
# 1002  http://awarenessact.com/jim-carreys-explanatio...
# 1003  http://bipartisanreport.com/2018/01/22/trumps-...
# 1004  http://www.familysecuritymatters.org/blog/deta...
#
#                                                 content  \
# 1000  New Crowdfunding Republic Lets you invest in N...
# 1001  Our friend Jeff M tips us that Gem State citiz...
# 1002  While a lot of people would not consider Jim C...
# 1003  During the 2016 presidential elections, then-c...
# ...

# %%
for chunk in df:
    
    for row in chunk.iterrows():
        try:
            hdf_file.put(row[1]['type'], row[1], format='table', append=True)
        except:
            display(row[1])
        break
    break
    
    
    
    # Group the rows in the dataframe by the value in a specified column
    #groups = chunk.groupby("type")

    # Write the groups to an HDF5 file    
    #for group_name, group_df in groups:
    #    hdf_file.put(group_name, group_df, data_columns=True)
    #break



    #for label in labels:
        # Create a group in the HDF5 file with the name of the type
    #    group = hdf_file.create_group(label)
        # Filter the rows in the dataframe that have the current type value
    #    filtered_df = chunk[chunk["type"] == label]

    #    group.create_dataset("data", data=filtered_df.to_dict("list"))
    #break
# Out:
# id                                                                  2
# domain                                                  express.co.uk
# type                                                            rumor
# url                 https://www.express.co.uk/news/science/738402/...
# content             Life is an illusion, at least on a quantum lev...
# scraped_at                                 2018-01-25 16:17:44.789555
# inserted_at                                2018-02-02 01:19:41.756632
# updated_at                                 2018-02-02 01:19:41.756664
# title               Is life an ILLUSION? Researchers prove 'realit...
# authors                                                   Sean Martin
# keywords                                                          NaN
# meta_keywords                                                    ['']
# meta_description    THE UNIVERSE ceases to exist when we are not l...
# ...

# %%
hdf_file.close()

# %%
next(df).head()
# Out:
#    id              domain   type  \
# 0   2       express.co.uk  rumor
# 1   6  barenakedislam.com   hate
# 2   7  barenakedislam.com   hate
# 3   8  barenakedislam.com   hate
# 4   9  barenakedislam.com   hate
#
#                                                  url  \
# 0  https://www.express.co.uk/news/science/738402/...
# 1  http://barenakedislam.com/category/donald-trum...
# 2  http://barenakedislam.com/category/donald-trum...
# 3  http://barenakedislam.com/2017/12/24/more-winn...
# 4  http://barenakedislam.com/2017/12/25/oh-trump-...
#
#                                              content  \
# 0  Life is an illusion, at least on a quantum lev...
# 1  Unfortunately, he hasn’t yet attacked her for ...
# 2  The Los Angeles Police Department has been den...
# 3  The White House has decided to quietly withdra...
# 4  “The time has come to cut off the tongues of t...
#
#                    scraped_at                 inserted_at  \
# ...
